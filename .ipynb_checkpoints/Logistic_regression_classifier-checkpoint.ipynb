# %% [markdown]
# ## Introduction

# %% [markdown]
# **Loading dataset**

# %%
# Pandas is used for data manipulation
import pandas as pd

# Read in data as pandas dataframe and display first 5 rows
features = pd.read_csv('input/electricity_consumption.csv')
features.head(5)
# Out:
#    Unnamed: 0 stat.socio dwelling.size dwelling.tenure2   region.f  \
# 0           1   mid-high        <201m2            Owned  Temperate
# 1          17    mid-low     151-200m2            Owned  Temperate
# 2          21   mid-high     151-200m2         Borrowed  Temperate
# 3          23   mid-high     101-150m2            Owned  Temperate
# 4          24   mid-high      76-100m2            Owned  Temperate
#
#           state.f municipality.pop ac.acquire  total_niv material.wall  ...  \
# 0  Aguascalientes            >100k         No          2         brick  ...
# 1  Aguascalientes            >100k         No          1         adobe  ...
# 2  Aguascalientes            >100k         No          2         brick  ...
# 3  Aguascalientes            >100k         No          1         brick  ...
# 4  Aguascalientes            >100k         No          1         brick  ...
#
#   material.floor antigua  cuart_dorm  fridge.adopt washing.adopt iron.adopt  \
# 0    wood/mosaic      40           5           Yes           Yes        Yes
# 1         cement      50           3            No           Yes         No
# 2    wood/mosaic      30           2           Yes           Yes         No
# 3    wood/mosaic      30           2           Yes           Yes        Yes
# 4    wood/mosaic      45           2           Yes           Yes        Yes
#
#   tv.adopt celphone.adopt fan.adopt cons.month.kwh.hig1
# 0      Yes            Yes       Yes          129.154069
# 1      Yes             No        No           52.860920
# 2      Yes            Yes       Yes          142.319660
# 3      Yes            Yes       Yes          108.572344
# 4      Yes            Yes       Yes           75.910042
#
# [5 rows x 21 columns]
